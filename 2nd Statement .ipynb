# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('Indicators.csv')
data.shape
# Out:
# (5656458, 6)

# %%
data.head(10)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
# 5  Arab World         ARB        Arms imports (SIPRI trend indicator values)
# 6  Arab World         ARB               Birth rate, crude (per 1,000 people)
# 7  Arab World         ARB                                 CO2 emissions (kt)
# 8  Arab World         ARB             CO2 emissions (metric tons per capita)
# 9  Arab World         ARB  CO2 emissions from gaseous fuel consumption (%...
#
#        IndicatorCode  Year         Value
# 0        SP.ADO.TFRT  1960  1.335609e+02
# ...

# %%
countries = data['CountryName'].unique().tolist()

# %%
hist_indicator = 'CO2 emissions'
hist_country = 'IND'

# %%
mask1 = data['IndicatorName'].str.contains(hist_indicator)
mask2 = data['CountryCode'].str.contains(hist_country)

# %%
stage = data[mask1 & mask2]

# %%
stage.head()
# Out:
#       CountryName CountryCode  \
# 11575       India         IND
# 11576       India         IND
# 11577       India         IND
# 11578       India         IND
# 11579       India         IND
#
#                                            IndicatorName      IndicatorCode  \
# 11575             CO2 emissions (kg per 2005 US$ of GDP)  EN.ATM.CO2E.KD.GD
# 11576                                 CO2 emissions (kt)     EN.ATM.CO2E.KT
# 11577             CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 11578  CO2 emissions from gaseous fuel consumption (%...  EN.ATM.CO2E.GF.ZS
# 11579   CO2 emissions from gaseous fuel consumption (kt)  EN.ATM.CO2E.GF.KT
#
#        Year          Value
# 11575  1960       1.174578
# 11576  1960  120581.961000
# 11577  1960       0.268161
# 11578  1960       0.000000
# 11579  1960       0.000000

# %%
years = stage['Year'].values
co2 = stage['Value'].values

# create
plt.bar(years,co2)
plt.show()

# %%
data = pd.read_csv('Indicators.csv')

# %%
data.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
hist_indicator = 'CO2 emissions'
hist_country = 'USA'

# %%
new1 = data['IndicatorName'].str.contains(hist_indicator)
new2 = data['CountryCode'].str.contains(hist_country)

# %%
stage1 = data[new1 & new2]
stage1.head()
# Out:
#          CountryName CountryCode  \
# 22230  United States         USA
# 22231  United States         USA
# 22232  United States         USA
# 22233  United States         USA
# 22234  United States         USA
#
#                                            IndicatorName      IndicatorCode  \
# 22230             CO2 emissions (kg per 2005 US$ of GDP)  EN.ATM.CO2E.KD.GD
# 22231                                 CO2 emissions (kt)     EN.ATM.CO2E.KT
# 22232             CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 22233  CO2 emissions from electricity and heat produc...     EN.CO2.ETOT.ZS
# 22234  CO2 emissions from gaseous fuel consumption (%...  EN.ATM.CO2E.GF.ZS
#
#        Year         Value
# 22230  1960  1.033397e+00
# 22231  1960  2.890696e+06
# 22232  1960  1.599978e+01
# 22233  1960  2.771343e+01
# 22234  1960  2.181276e+01

# %%
years = stage1['Year'].values
co2 = stage1['Value'].values

# %%
plt.bar(years,co2)
plt.show()

# %%
sns.jointplot(x = years, y = co2, data = stage1, color = 'green')

# %%
sns.jointplot(x = years, y = co2, data = stage1, kind = 'hex')

# %%
sns.jointplot(x = years, y = co2, data = stage1, kind = 'kde')

# %%
sns.pairplot(stage1)

# %%
x = sns.PairGrid(stage1)
x = x.map(plt.scatter)
