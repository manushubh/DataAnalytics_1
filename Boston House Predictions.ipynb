# %%
import sklearn
from sklearn.datasets import load_boston

# %%
import pandas as pd
boston=load_boston()
X=pd.DataFrame(boston.data,columns=boston.feature_names)
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y=boston.target
print(y.shape)
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 36.92592920612224
# [-9.73760191e-02  6.03267462e-02  6.91409877e-02  1.33306449e+00
#  -1.59740636e+01  3.40758630e+00 -1.57969452e-03 -1.38319873e+00
#   3.22762929e-01 -1.63681370e-02 -9.01618474e-01  1.03994478e-02
#  -5.15297473e-01]

# %%
y_pred=linreg.predict(X_test)

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

# %%
score
# Out:
# 0.7133945926032297

# %%
import matplotlib.pyplot as plt

# %%
fig,ax=plt.subplots(5,3,figsize=(12,12))
plt.tight_layout()
j=0
k=0
for i in range(5):
    if k<13:
        ax[i][j].scatter(X[boston.feature_names[k]],boston.target)
        k+=1
